# %%
import pandas as pd
import numpy as np

# %%
path_players = "../data/aggregates/aus1league_physicalaggregates_20242025_midfielders.csv"

# %%
df = pd.read_csv(path_players)

# %%
df['player_name'] = df['player_name'].str.replace(r'\s+', ' ', regex=True).str.strip()

# %%
df.dropna(axis=1, inplace=True)
df['unique_id'] = df['player_name'] + " (" + df['position_group'] + ")"

# %%
df
# Out:
#                 player_name player_short_name  player_id  \
# 0              Adam Taggart        A. Taggart        211
# 1              Adama Traoré         A. Traoré        218
# 2           Dino Arslanagić     D. Arslanagić       2759
# 3    Douglas Costa de Souza     Douglas Costa       2858
# 4    Douglas Costa de Souza     Douglas Costa       2858
# ..                      ...               ...        ...
# 401        Fabian Talladira      F. Talladira     973078
# 402        Kyle Reilly Shaw           K. Shaw     998256
# 403           Austin Ludwik         A. Ludwik     998558
# 404          Harry Crawford       H. Crawford     998842
# 405          Harry Crawford       H. Crawford    1002177
#
#                            team_name  team_id competition_name  \
# 0          Perth Glory Football Club      871   AUS - A-League
# 1    Melbourne Victory Football Club      868   AUS - A-League
# 2                       Macarthur FC     1804   AUS - A-League
# ...

# %%
df.describe()
# Out:
#           player_id      team_id  competition_id  season_id  minutes_full_all  \
# count  4.060000e+02   406.000000           406.0      406.0        406.000000
# mean   3.727617e+05  1586.056650            61.0       95.0         86.303916
# std    3.748094e+05   889.820595             0.0        0.0         11.614877
# min    2.110000e+02   866.000000            61.0       95.0         60.350000
# 25%    4.560900e+04   869.000000            61.0       95.0         77.192500
# 50%    1.336765e+05  1802.000000            61.0       95.0         89.225000
# 75%    7.955155e+05  1805.000000            61.0       95.0         96.537500
# max    1.002177e+06  4177.000000            61.0       95.0        104.580000
#
#        minutes_full_tip  minutes_full_otip  count_match  count_match_failed  \
# count        406.000000         406.000000   406.000000          406.000000
# mean          24.031897          24.384138     8.051724            0.049261
# ...

# %%
import sys
sys.path.append("../scripts")  # adjust the path if needed
from utils import *

# %%
similarity_df = compute_similarity(df)

# %%
df["player_name"].unique()
# Out:
# array(['Adam Taggart', 'Adama Traoré', 'Dino Arslanagić',
#        'Douglas Costa de Souza', 'Hiroki Sakai', 'Javi López',
#        'Joshua Brillante', 'Juan Manuel Mata García', 'Kévin Boli',
#        'Marco Rojas', 'Marin Jakoliš', 'Mathew Leckie',
#        'Roderick Jefferson Gonçalves Miranda', 'Samuel Souprayen',
#        'Trent Sainsbury', 'Valère Germain', 'Zinédine Machach',
#        'Daniel Arzani', 'Andrew Nabbout', 'Aziz Eraltay Behich',
#        'Matthew Jurman', 'Josh Risdon', 'Saîf-Eddine Khaoui', 'Luke Amos',
#        'Francisco de Oliveira Geraldes', 'Alex Gersbach',
#        'Bozhidar Kraev', 'Marcus Antonsson', 'Louis Verstraete',
#        'Patryk Klimala', 'Joe Lolley', 'Ben Folami', 'Ryan Edmondson',
#        'Brandon Borrello', 'Yonatan Cohen', 'Luis Felipe Gallegos Leiva',
#        'James Donachie', 'Jason Geria', "Brandon O'Neill",
#        'Kosta Barbarouses', 'Ben Garuccio', 'Ryan Kitto',
# ...

# %%
df[df["player_name"]== "Valère Germain"]
# Out:
#        player_name player_short_name  player_id     team_name  team_id  \
# 24  Valère Germain        V. Germain      10623  Macarthur FC     1804
# 25  Valère Germain        V. Germain      10623  Macarthur FC     1804
#
#    competition_name  competition_id season_name  season_id  position_group  \
# 24   AUS - A-League              61   2024/2025         95  Center Forward
# 25   AUS - A-League              61   2024/2025         95   Wide Attacker
#
#     ...  sprint_count_full_otip  hi_distance_full_otip  hi_count_full_otip  \
# 24  ...                    0.88                 137.62                12.5
# 25  ...                    1.00                 101.00                11.0
#
#     medaccel_count_full_otip  highaccel_count_full_otip  \
# 24                      29.5                       1.81
# 25                      29.0                       2.00
#
#     meddecel_count_full_otip  highdecel_count_full_otip  \
# 24                     27.12                       2.81
# ...

# %%
get_similar_players(df, similarity_df, player_name="Valère Germain", position_group = "Center Forward", top_n=15, filter_col="position_group")
# Out:
#                                           unique_id  \
# 0                     Harry Sawyer (Center Forward)
# 1           Douglas Costa de Souza (Center Forward)
# 2   Antonio Mikael Rodrigues Brito (Center Forward)
# 3                  Nikolaos Vergos (Center Forward)
# 4            Asumah Abubakar-Ankra (Center Forward)
# 5                       Max Caputo (Center Forward)
# 6                 Marcus Antonsson (Center Forward)
# 7            Bruno Fornaroli Mezza (Center Forward)
# 8                       Joe Lolley (Center Forward)
# 9                Nicolas Milanovic (Center Forward)
# 10                 Miguel Di Pizio (Center Forward)
# 11                     Ariath Piol (Center Forward)
# 12                    Medin Memeti (Center Forward)
# 13                    Jake Hollman (Center Forward)
# 14                    Reno Piscopo (Center Forward)
#
#                        player_name                             team_name  \
# ...

# %%
df.head()
# Out:
#               player_name player_short_name  player_id  \
# 0            Adam Taggart        A. Taggart        211
# 1            Adama Traoré         A. Traoré        218
# 2         Dino Arslanagić     D. Arslanagić       2759
# 3  Douglas Costa de Souza     Douglas Costa       2858
# 4  Douglas Costa de Souza     Douglas Costa       2858
#
#                          team_name  team_id competition_name  competition_id  \
# 0        Perth Glory Football Club      871   AUS - A-League              61
# 1  Melbourne Victory Football Club      868   AUS - A-League              61
# 2                     Macarthur FC     1804   AUS - A-League              61
# 3             Sydney Football Club      869   AUS - A-League              61
# 4             Sydney Football Club      869   AUS - A-League              61
#
#   season_name  season_id    position_group  ...  sprint_count_full_otip  \
# 0   2024/2025         95    Center Forward  ...                    3.00
# ...

# %%
df["player_name"].unique()
# Out:
# array(['Adam Taggart', 'Adama Traoré', 'Dino Arslanagić',
#        'Douglas Costa de Souza', 'Hiroki Sakai', 'Javi López',
#        'Joshua Brillante', 'Juan Manuel Mata García', 'Kévin Boli',
#        'Marco Rojas', 'Marin Jakoliš', 'Mathew Leckie',
#        'Roderick Jefferson Gonçalves Miranda', 'Samuel Souprayen',
#        'Trent Sainsbury', 'Valère Germain', 'Zinédine Machach',
#        'Daniel Arzani', 'Andrew Nabbout', 'Aziz Eraltay Behich',
#        'Matthew Jurman', 'Josh Risdon', 'Saîf-Eddine Khaoui', 'Luke Amos',
#        'Francisco de Oliveira Geraldes', 'Alex Gersbach',
#        'Bozhidar Kraev', 'Marcus Antonsson', 'Louis Verstraete',
#        'Patryk Klimala', 'Joe Lolley', 'Ben Folami', 'Ryan Edmondson',
#        'Brandon Borrello', 'Yonatan Cohen', 'Luis Felipe Gallegos Leiva',
#        'James Donachie', 'Jason Geria', "Brandon O'Neill",
#        'Kosta Barbarouses', 'Ben Garuccio', 'Ryan Kitto',
# ...

# %%
df[df['player_name'] == "Douglas Costa de Souza "]
# Out:
# Empty DataFrame
# ...

# %%
df.loc[df['unique_id'] == "Douglas Costa de Souza (Center Forward)", used_features].values.flatten()
# Out:
# array([9.425000e+01, 2.743000e+01, 2.481000e+01, 4.000000e+00,
#        0.000000e+00, 1.052125e+04, 1.116400e+02, 1.425500e+03,
#        4.067500e+02, 3.600000e+01, 7.125000e+01, 4.250000e+00,
#        4.780000e+02, 4.025000e+01, 9.150000e+01, 6.500000e+00,
#        7.400000e+01, 1.050000e+01, 3.250000e+00, 5.000000e-01,
#        2.638000e+01, 2.638000e+01, 3.782500e+03, 1.379200e+02,
#        6.327500e+02, 1.865000e+02, 1.675000e+01, 3.925000e+01,
#        1.750000e+00, 2.257500e+02, 1.850000e+01, 4.100000e+01,
#        2.750000e+00, 2.650000e+01, 3.750000e+00, 1.500000e+00,
#        0.000000e+00, 3.652500e+03, 1.472300e+02, 6.620000e+02,
#        1.992500e+02, 1.550000e+01, 2.800000e+01, 2.000000e+00,
#        2.272500e+02, 1.750000e+01, 2.875000e+01, 2.000000e+00,
#        2.500000e+01, 3.000000e+00, 7.500000e-01, 2.500000e-01])

# %%
import pandas as pd
import numpy as np

def feature_contributions(df, player1, position_group1, player2, position_group2, feature_cols):
    # Extraire les vecteurs
    player_key_1 = f"{player1} ({position_group1})"
    player_key_2 = f"{player2} ({position_group2})"
    v1 = df.loc[df['unique_id'] == player_key_1, feature_cols].values.flatten()
    v2 = df.loc[df['unique_id'] == player_key_2, feature_cols].values.flatten()

    # Calculer la contribution brute
    contributions = v1 * v2

    # Normalisation (comme dans la cosine similarity)
    norm_factor = np.linalg.norm(v1) * np.linalg.norm(v2)
    contributions_normalized = contributions / norm_factor

    # Mettre dans un DataFrame
    contrib_df = pd.DataFrame({
        'feature': feature_cols,
        'contribution': contributions_normalized
    }).sort_values(by='contribution', ascending=False)

    return contrib_df

# %%
player1 = "Valère Germain"
position_group1 = "Center Forward"
player2 = "Douglas Costa de Souza"
position_group2 = "Center Forward"
used_features = df.drop(columns = ["player_name", 'player_name',
 'player_short_name',
 'player_id',
 'team_name',
 'team_id',
 'competition_name',
 'competition_id',
 'season_name',
 'season_id',
 'position_group','unique_id']).columns.tolist()
contribs = feature_contributions(df, player1,position_group1, player2,position_group2, used_features)
contribs.head(10)
# Out:
#                        feature  contribution
# 5      total_distance_full_all      0.781944
# 22     total_distance_full_tip      0.104825
# 37    total_distance_full_otip      0.090046
# 7    running_distance_full_all      0.012317
# 24   running_distance_full_tip      0.003004
# 39  running_distance_full_otip      0.002027
# 12        hi_distance_full_all      0.001835
# 8        hsr_distance_full_all      0.001231
# 29        hi_distance_full_tip      0.000587
# 25       hsr_distance_full_tip      0.000374

# %%
import matplotlib.pyplot as plt

top = contribs.head(10)
plt.barh(top['feature'], top['contribution'])
plt.gca().invert_yaxis()
plt.title(f"Top 10 features contributing to similarity between {player1} and {player2}")
plt.xlabel("Normalized contribution")
plt.show()
